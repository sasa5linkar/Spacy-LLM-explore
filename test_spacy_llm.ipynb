# %%
from constants import arhiva2022, RESUORCES_DIR
from util_spacy import xml_path, load_data_from_xml
from spacy_llm.util import assemble

nlp = assemble("llm.cfg")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
df = load_data_from_xml(xml_path(arhiva2022))

# %%
random_sample = df.sample()
print(random_sample)
# Out:
#                                            title  \
# 12231  RADOVAN BELI MARKOVIĆ U KUĆI ĐURE JAKŠIĆA
#
#                                                     text             author  \
# 12231  Na vest o smrti Radovana Belog Markovića, pože...  SRBOLJUB ĐORĐEVIĆ
#
#             date newspaper category
# 12231  2.2.2022.  Politika  Kultura

# %%
doc = nlp(random_sample.iloc[0].text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_49544\248835372.py in ?()
# ----> 1 doc = nlp(random_sample.iloc[0].text)
#
# e:\Github\Spacy-LLM-explore\env\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'text'

# %%
doc.cats
# Out:
# {'Civilno društvo': 0.0,
#  'EU': 0.0,
#  'Ekologija': 0.0,
#  'Ekonomija i finansije': 0.0,
#  'Energetika i rudarstvo': 0.0,
#  'Estrada/Zabava': 0.0,
#  'Infrastruktura': 0.0,
#  'Istorijske teme': 0.0,
#  'Korupcija': 0.0,
#  'Kosovo': 0.0,
#  'Kriminal': 0.0,
#  'Kultura': 0.0,
#  'Ljudska prava': 0.0,
#  'Mediji': 0.0,
#  'Nauka': 0.0,
#  'Nesreće i elementarne nepogode': 0.0,
#  'Obrazovanje': 0.0,
#  'Ostale društvene teme': 0.0,
#  'Policija': 0.0,
#  'Politika': 0.0,
#  'Poljoprivreda': 0.0,
#  'Pravosuđe': 0.0,
#  'Privreda': 0.0,
#  'Ratni zločini/Haški tribunal': 0.0,
#  'Region': 0.0,
#  'Religija': 0.0,
#  'Saobraćaj': 0.0,
#  'Socijalna politika': 0.0,
#  'Spoljna politika': 0.0,
#  'Sport': 0.0,
#  'Svet': 0.0,
#  'Telekomunikacije i informatika': 0.0,
#  'Vojska': 0.0,
#  'Zaštita prava potrošača': 0.0,
#  'Zdravstvo': 0.0}

# %%
import pandas as pd

# Assuming doc.cats is a dictionary
df2 = pd.DataFrame(list(doc.cats.items()), columns=['Category', 'Score'])
df2
# Out:
#                           Category  Score
# 0                  Civilno društvo    0.0
# 1                               EU    0.0
# 2                        Ekologija    0.0
# 3            Ekonomija i finansije    0.0
# 4           Energetika i rudarstvo    0.0
# 5                   Estrada/Zabava    0.0
# 6                   Infrastruktura    0.0
# 7                  Istorijske teme    0.0
# 8                        Korupcija    0.0
# 9                           Kosovo    0.0
# 10                        Kriminal    0.0
# 11                         Kultura    0.0
# 12                   Ljudska prava    0.0
# 13                          Mediji    0.0
# 14                           Nauka    0.0
# 15  Nesreće i elementarne nepogode    0.0
# 16                     Obrazovanje    0.0
# 17           Ostale društvene teme    0.0
# 18                        Policija    0.0
# 19                        Politika    0.0
# 20                   Poljoprivreda    0.0
# 21                       Pravosuđe    0.0
# 22                        Privreda    0.0
# 23    Ratni zločini/Haški tribunal    0.0
# 24                          Region    0.0
# 25                        Religija    0.0
# 26                       Saobraćaj    0.0
# 27              Socijalna politika    0.0
# 28                Spoljna politika    0.0
# 29                           Sport    0.0
# 30                            Svet    0.0
# 31  Telekomunikacije i informatika    0.0
# 32                          Vojska    0.0
# 33         Zaštita prava potrošača    0.0
# 34                       Zdravstvo    0.0
